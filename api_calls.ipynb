# %% [markdown]
# # Test API Responses
# This notebook is used to submit requests to the API endpoints generated by the R model (in the script model_build.R)

# %%
# Load Required Library

import requests

# %%
# Submit API request

resp = requests.get("http://127.0.0.1/predict_survival_prob?sex=female&age=80&class=1")

print(resp.content)
# Out:
# b'[0.6939]'

# %%
# Modifying the input features

resp = requests.get("http://127.0.0.1/predict_survival_prob?sex=male&age=30&class=3")

print(resp.content)
# Out:
# b'[0.0805]'
